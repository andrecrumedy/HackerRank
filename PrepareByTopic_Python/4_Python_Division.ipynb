# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())

    print(
        str((int(a/b))) + '\n'\
         + str(a/b)
    )
# Out:
# 0
# 0.5
