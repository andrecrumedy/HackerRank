# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from __future__ import print_function
if __name__ == '__main__':
    n = int(input())

    for i in range(1, n+1):
        print(i, end='')
# Out:
# 12345

# %% [markdown]
# `note:` the print function has input options to help with formatting
# ![image.png](attachment:image.png)
