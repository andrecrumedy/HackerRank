# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())

    print( str(a+b) + '\n'\
        + str(a-b) + '\n'\
        + str(a*b) + '\n'
          )
# Out:
# 5
# 1
# 6

# %% [markdown]
# `note:` print(value_1, value_2, valu3) will add a extra space after each value
