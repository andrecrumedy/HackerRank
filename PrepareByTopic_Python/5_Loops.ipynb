# %% [markdown]
# ![  ](attachment:image.png)

# %%
if __name__ == '__main__':
    n = int(input())

    if n >= 0:
        for num in range(n):
            print(
                str(num**2)
            )
# Out:
# 1
# 4
# 9
# 16
# 25
